# %% [markdown]
# # Preprocess
# #### Takes raw numpy arrays, converts them to dataframes,  generates jet images, and normalizes variables

# %% [markdown]
# ## Setup

# %%
import os
import time

import numpy as np
seed = 7
np.random.seed(seed)
import pandas as pd

import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

from utils import profile_data

# %%
####################
# Global Variables #
####################
radius = 'ak5' # Jet radius to use. Either 'ak5' or 'ak7'
jet_pt_cut = 15

nx = 25 if radius == 'ak5' else 30 # size of image in eta
ny = 25 if radius == 'ak5' else 30 # size of image in phi
xbins = np.linspace(-1.0,1.0,nx+1)
ybins = np.linspace(-1.0,1.0,ny+1)

# %% [markdown]
# ## Functions

# %%
def make_jet_images(df_jets, df_cands):
    njets = len(df_jets)
    # Particle types
    pids = {'ch':[1,2,211,-211], 'nh':[130], 'el+mu+ph':[11,-11, 13,-13, 22]}
    jet_images=np.zeros((njets, nx, ny, len(pids))) # 4D tensor with indices: jet index, eta, phi, particle type

    for ijet in range(0, njets):
        
        if ijet%10000==0: print('\tProcessed {} events out of {}'.format(ijet, njets))

        # Get the pf cands of the ith jet by matching the jet to its pf cands
        df_cand_i = df_cands[(df_cands['pfcand_ijet'] == df_jets['pfcand_ijet'].iloc[ijet]) &
                             (df_cands['event'] == df_jets['event'].iloc[ijet]) &
                             (df_cands['jet_pt'] == df_jets['jet_pt'].iloc[ijet])]

        # Get the center of the jet (i.e. eta, phi of highest pt pf cand)
        x0 = df_cand_i['pfcand_eta'].iloc[0]
        y0 = df_cand_i['pfcand_phi'].iloc[0]
        
        # Separate by particle types
        for ipid, (_, pid) in enumerate(pids.items()):

            df_cand_p = df_cand_i[df_cand_i['pfcand_id'].isin(pid)]
            
            # Get position relative to center of jet
            x = df_cand_p['pfcand_eta'] - x0
            y = df_cand_p['pfcand_phi'] - y0
            weights = df_cand_p['pfcand_pt'] # pt of candidate is the weight
        
            # Create a 2D histogram representing the jet image and then convert to an array
            hist, xedges, yedges = np.histogram2d(x.values, y.values, weights=weights, bins=(xbins,ybins))
            jet_images[ijet,:,:,ipid] = hist
    
    return jet_images

# %%
def process_one(infile):
    start = time.clock()
    
    # Load file
    data = np.load(infile)
    
    # Create dataframes holding the jet-level information and pf candidate-level information
    df_jets = pd.DataFrame(data,columns=['run','lumi','event','met','sumet','rho','pthat','mcweight','njet','jet_pt','jet_eta','jet_phi','jet_E','jet_area','jet_jes','gen_pt','jet_gen_dr',
                                                  'chf','nhf','phf','elf','muf','hf_hf','hf_phf','hf_hm','hf_phm','chm','nhm','phm','elm','mum','beta','bstar','pfcand_ijet'])
    df_jets = df_jets.drop_duplicates()
    df_jets = df_jets[(df_jets.jet_pt > jet_pt_cut)]

    df_cands = pd.DataFrame(data, columns=['event', 'jet_pt', 'jet_eta', 'jet_phi','pfcand_pt', 'pfcand_eta', 'pfcand_phi', 'pfcand_id', 'pfcand_charge', 'pfcand_ijet'])
    df_cands = df_cands[(df_cands.jet_pt > jet_pt_cut)]
      
    # Add response to dataframe
    df_jets['jet_resp'] = df_jets['jet_pt']/df_jets['gen_pt']
        
    # Make jet images
    jet_images = make_jet_images(df_jets, df_cands)
    # Add jet images to dataframe
    df_jets['jet_images'] = [x for x in jet_images]

    end = time.clock()
    mins = (end-start)/60.
    
    print('\n\tFinished file in {:.2f} minutes ({:.2f} events/minute)\n'.format(mins, len(df_jets)/mins))
    return df_jets

# %% [markdown]
# ## Processing

# %% [markdown]
# #### Process each file individually

# %%
first_file, last_file = 21, 30
files = ['/uscms_data/d3/rohanb/deepjec/{}/unprocessed/{}PFJetsParams0_{}.npy'.format(radius, radius, x) for x in range(first_file, last_file+1)]

# %%
for i, infile in enumerate(files, first_file):
    if i==(8 or 141): continue; # Missing file 8 and 141
    print('File {} out of {}'.format(i, last_file))
    df = process_one(infile)
    # Save files as you go, so you don't always have to run over all files
    df.to_pickle('/uscms_data/d3/rohanb/deepjec/{}/df_jets_{}_{}.pkl'.format(radius, radius, i))
# Out:
# File 21 out of 30
# 	Processed 0 events out of 169981
# 	Processed 10000 events out of 169981
# 	Processed 20000 events out of 169981
# 	Processed 30000 events out of 169981
# 	Processed 40000 events out of 169981
# 	Processed 50000 events out of 169981
# 	Processed 60000 events out of 169981
# 	Processed 70000 events out of 169981
# 	Processed 80000 events out of 169981
# 	Processed 90000 events out of 169981
# 	Processed 100000 events out of 169981
# 	Processed 110000 events out of 169981
# 	Processed 120000 events out of 169981
# 	Processed 130000 events out of 169981
# 	Processed 140000 events out of 169981
# 	Processed 150000 events out of 169981
# 	Processed 160000 events out of 169981
#
# 	Finished file in 78.78 minutes (2157.78 events/minute)
#
# File 22 out of 30
# 	Processed 0 events out of 189406
# 	Processed 10000 events out of 189406
# 	Processed 20000 events out of 189406
# 	Processed 30000 events out of 189406
# 	Processed 40000 events out of 189406
# 	Processed 50000 events out of 189406
# 	Processed 60000 events out of 189406
# 	Processed 70000 events out of 189406
# 	Processed 80000 events out of 189406
# 	Processed 90000 events out of 189406
# 	Processed 100000 events out of 189406
# 	Processed 110000 events out of 189406
# 	Processed 120000 events out of 189406
# 	Processed 130000 events out of 189406
# 	Processed 140000 events out of 189406
# 	Processed 150000 events out of 189406
# 	Processed 160000 events out of 189406
# 	Processed 170000 events out of 189406
# 	Processed 180000 events out of 189406
#
# 	Finished file in 86.88 minutes (2180.01 events/minute)
#
# File 23 out of 30
# 	Processed 0 events out of 179590
# 	Processed 10000 events out of 179590
# 	Processed 20000 events out of 179590
# 	Processed 30000 events out of 179590
# 	Processed 40000 events out of 179590
# 	Processed 50000 events out of 179590
# 	Processed 60000 events out of 179590
# 	Processed 70000 events out of 179590
# 	Processed 80000 events out of 179590
# 	Processed 90000 events out of 179590
# 	Processed 100000 events out of 179590
# 	Processed 110000 events out of 179590
# 	Processed 120000 events out of 179590
# 	Processed 130000 events out of 179590
# 	Processed 140000 events out of 179590
# 	Processed 150000 events out of 179590
# 	Processed 160000 events out of 179590
# 	Processed 170000 events out of 179590
#
# 	Finished file in 78.50 minutes (2287.83 events/minute)
#
# File 24 out of 30
# 	Processed 0 events out of 145434
# 	Processed 10000 events out of 145434
# 	Processed 20000 events out of 145434
# 	Processed 30000 events out of 145434
# 	Processed 40000 events out of 145434
# 	Processed 50000 events out of 145434
# 	Processed 60000 events out of 145434
# 	Processed 70000 events out of 145434
# 	Processed 80000 events out of 145434
# 	Processed 90000 events out of 145434
# 	Processed 100000 events out of 145434
# 	Processed 110000 events out of 145434
# 	Processed 120000 events out of 145434
# 	Processed 130000 events out of 145434
# 	Processed 140000 events out of 145434
#
# 	Finished file in 55.73 minutes (2609.85 events/minute)
#
# File 25 out of 30
# 	Processed 0 events out of 170601
# 	Processed 10000 events out of 170601
# 	Processed 20000 events out of 170601
# 	Processed 30000 events out of 170601
# 	Processed 40000 events out of 170601
# 	Processed 50000 events out of 170601
# 	Processed 60000 events out of 170601
# 	Processed 70000 events out of 170601
# 	Processed 80000 events out of 170601
# 	Processed 90000 events out of 170601
# 	Processed 100000 events out of 170601
# 	Processed 110000 events out of 170601
# 	Processed 120000 events out of 170601
# 	Processed 130000 events out of 170601
# 	Processed 140000 events out of 170601
# 	Processed 150000 events out of 170601
# 	Processed 160000 events out of 170601
# 	Processed 170000 events out of 170601
#
# 	Finished file in 72.83 minutes (2342.30 events/minute)
#
# File 26 out of 30
# 	Processed 0 events out of 151545
# 	Processed 10000 events out of 151545
# 	Processed 20000 events out of 151545
# 	Processed 30000 events out of 151545
# 	Processed 40000 events out of 151545
# 	Processed 50000 events out of 151545
# 	Processed 60000 events out of 151545
# 	Processed 70000 events out of 151545
# 	Processed 80000 events out of 151545
# 	Processed 90000 events out of 151545
# 	Processed 100000 events out of 151545
# 	Processed 110000 events out of 151545
# 	Processed 120000 events out of 151545
# 	Processed 130000 events out of 151545
# 	Processed 140000 events out of 151545
# 	Processed 150000 events out of 151545
#
# 	Finished file in 61.50 minutes (2464.33 events/minute)
#
# File 27 out of 30
# 	Processed 0 events out of 181309
# 	Processed 10000 events out of 181309
# 	Processed 20000 events out of 181309
# 	Processed 30000 events out of 181309
# 	Processed 40000 events out of 181309
# 	Processed 50000 events out of 181309
# 	Processed 60000 events out of 181309
# 	Processed 70000 events out of 181309
# 	Processed 80000 events out of 181309
# 	Processed 90000 events out of 181309
# 	Processed 100000 events out of 181309
# 	Processed 110000 events out of 181309
# 	Processed 120000 events out of 181309
# 	Processed 130000 events out of 181309
# 	Processed 140000 events out of 181309
# 	Processed 150000 events out of 181309
# 	Processed 160000 events out of 181309
# 	Processed 170000 events out of 181309
# 	Processed 180000 events out of 181309
#
# 	Finished file in 82.17 minutes (2206.43 events/minute)
#
# File 28 out of 30
# 	Processed 0 events out of 155279
# 	Processed 10000 events out of 155279
# 	Processed 20000 events out of 155279
# 	Processed 30000 events out of 155279
# 	Processed 40000 events out of 155279
# 	Processed 50000 events out of 155279
# 	Processed 60000 events out of 155279
# 	Processed 70000 events out of 155279
# 	Processed 80000 events out of 155279
# 	Processed 90000 events out of 155279
# 	Processed 100000 events out of 155279
# 	Processed 110000 events out of 155279
# 	Processed 120000 events out of 155279
# 	Processed 130000 events out of 155279
# 	Processed 140000 events out of 155279
# 	Processed 150000 events out of 155279
#
# 	Finished file in 60.77 minutes (2555.13 events/minute)
#
# File 29 out of 30
# 	Processed 0 events out of 163076
# 	Processed 10000 events out of 163076
# 	Processed 20000 events out of 163076
# 	Processed 30000 events out of 163076
# 	Processed 40000 events out of 163076
# 	Processed 50000 events out of 163076
# 	Processed 60000 events out of 163076
# 	Processed 70000 events out of 163076
# 	Processed 80000 events out of 163076
# 	Processed 90000 events out of 163076
# 	Processed 100000 events out of 163076
# 	Processed 110000 events out of 163076
# 	Processed 120000 events out of 163076
# 	Processed 130000 events out of 163076
# 	Processed 140000 events out of 163076
# 	Processed 150000 events out of 163076
# 	Processed 160000 events out of 163076
#
# 	Finished file in 67.91 minutes (2401.33 events/minute)
#
# File 30 out of 30
# 	Processed 0 events out of 211288
# 	Processed 10000 events out of 211288
# 	Processed 20000 events out of 211288
# 	Processed 30000 events out of 211288
# 	Processed 40000 events out of 211288
# 	Processed 50000 events out of 211288
# 	Processed 60000 events out of 211288
# 	Processed 70000 events out of 211288
# 	Processed 80000 events out of 211288
# 	Processed 90000 events out of 211288
# 	Processed 100000 events out of 211288
# 	Processed 110000 events out of 211288
# 	Processed 120000 events out of 211288
# 	Processed 130000 events out of 211288
# 	Processed 140000 events out of 211288
# 	Processed 150000 events out of 211288
# 	Processed 160000 events out of 211288
# 	Processed 170000 events out of 211288
# 	Processed 180000 events out of 211288
# 	Processed 190000 events out of 211288
# 	Processed 200000 events out of 211288
# 	Processed 210000 events out of 211288
#
# 	Finished file in 106.16 minutes (1990.29 events/minute)

# %% [markdown]
# #### Concat all the files together

# %%
dfs = []
for i in range(first_file, last_file+1):
    if i==8: continue; # Missing file 8    
    dfs.append(pd.read_pickle('/uscms_data/d3/rohanb/deepjec/{}/df_jets_{}_{}.pkl'.format(radius, radius, i)))

df_all = pd.concat(dfs)

print('Dataframe shape:\n\t{}'.format(df_all.shape))
print('Dataframe columns:\n\t{}'.format(df_all.columns))
# Out:
# Dataframe shape:
# 	(993416, 36)
# Dataframe columns:
# 	Index([u'run', u'lumi', u'event', u'met', u'sumet', u'rho', u'pthat',
#        u'mcweight', u'njet', u'jet_pt', u'jet_eta', u'jet_phi', u'jet_E',
#        u'jet_area', u'jet_jes', u'gen_pt', u'jet_gen_dr', u'chf', u'nhf',
#        u'phf', u'elf', u'muf', u'hf_hf', u'hf_phf', u'hf_hm', u'hf_phm',
#        u'chm', u'nhm', u'phm', u'elm', u'mum', u'beta', u'bstar',
#        u'pfcand_ijet', u'jet_resp', u'jet_images'],
#       dtype='object')

# %% [markdown]
# #### Remove all entries with gen_pt < 0 (where jet matching failed)

# %%
df_all = df_all[df_all.gen_pt>=0]
print('Number of events = {}'.format(len(df_all)))
# Out:
# Number of events = 955985

# %% [markdown]
# ## Plots

# %% [markdown]
# #### Check to make sure the variables look okay

# %%
# Average jet image
avg_image = np.sum(df_all.jet_images)/len(df_all)

fig, ax = plt.subplots()
cax = ax.matshow(avg_image.reshape((nx, ny)), norm=mpl.colors.LogNorm())
cbar = fig.colorbar(cax, ticks=[0.0000001, 0.00001, 0.001, 0.1, 1, 10, 100])

# %%
bins=np.linspace(0.8,1.2,20)
plt.figure()
plt.hist(df_all['gen_pt']/df_all['jet_pt'], label='gen/reco pT', alpha=0.5, bins=bins, normed=True)
plt.hist(df_all['jet_jes'], label='JES', alpha=0.5, bins=bins, normed=True)
plt.legend()
plt.show()

# %%
profile_data(df_all['jet_pt'], [df_all['jet_jes'], df_all['gen_pt']/df_all['jet_pt']], 100, 15, 3015, ['b','r'], plabels=['JES', 'gen/reco pT'], xlabel='Reco pT',ylim=(0.95,1.10))

# %%
profile_data(df_all['jet_eta'], [df_all['jet_jes'], df_all['gen_pt']/df_all['jet_pt']], 20, -5.0, 5.0, ['b','r'], plabels=['JES', 'gen/reco pT'], xlabel='Reco eta')

# %%
profile_data(df_all['chf'], [df_all['jet_jes'], df_all['gen_pt']/df_all['jet_pt']], 20, 0, 1, ['b','r'], plabels=['JES', 'gen/reco pT'], xlabel='CHF')

# %%
profile_data(df_all['nhf'], [df_all['jet_jes'], df_all['gen_pt']/df_all['jet_pt']], 20, 0, 1, ['b','r'], plabels=['JES', 'gen/reco pT'], xlabel='NHF')

# %%
profile_data(df_all['phf'], [df_all['jet_jes'], df_all['gen_pt']/df_all['jet_pt']], 20, 0, 1, ['b','r'], plabels=['JES', 'gen/reco pT'], xlabel='PHF')

# %%
profile_data(df_all['elf'], [df_all['jet_jes'], df_all['gen_pt']/df_all['jet_pt']], 20, 0, 1, ['b','r'], plabels=['JES', 'gen/reco pT'], xlabel='ELF')

# %%
profile_data(df_all['muf'], [df_all['jet_jes'], df_all['gen_pt']/df_all['jet_pt']], 20, 0, 1, ['b','r'], plabels=['JES', 'gen/reco pT'], xlabel='MUF')

# %%
plt.figure()
bins = np.linspace(0.9, 1.1, 50)
plt.hist(df_all['jet_jes'][(df_all['jet_pt']>150) & 
                             (df_all['jet_pt']<180) & 
                             (df_all['jet_eta']>-0.5) & 
                             (df_all['jet_eta']<0.5)], bins, label='150<pt<180, |eta|<0.5', alpha=0.5, normed=True)
plt.hist(df_all['jet_jes'][(df_all['jet_pt']>150) & 
                             (df_all['jet_pt']<180) & 
                             (df_all['jet_eta']>-0.5) & 
                             (df_all['jet_eta']<0.5) &
                             (df_all['chm'] > 10)], bins, label='150<pt<180, |eta|<0.5, chm > 10', alpha=0.5, normed=True)
plt.hist(df_all['jet_jes'][(df_all['jet_pt']>150) & 
                             (df_all['jet_pt']<180) & 
                             (df_all['jet_eta']>-0.5) & 
                             (df_all['jet_eta']<0.5) &
                             (df_all['chm'] < 10)], bins, label='150<pt<180, |eta|<0.5, chm < 10', alpha=0.5, normed=True)
plt.xlabel('Jet Energy Scale')
plt.legend(loc='upper left')
plt.show()

# %%
plt.figure()
plt.hist2d(df_all['jet_pt'], df_all['chm'], bins=(100, 60), norm=mpl.colors.LogNorm())
plt.colorbar()
plt.xlabel('jet_pt')
plt.ylabel('chm')
plt.show()
plt.figure()
plt.hist2d(df_all['jet_eta'], df_all['chm'], bins=(100, 60), norm=mpl.colors.LogNorm())
plt.colorbar()
plt.xlabel('jet_eta')
plt.ylabel('chm')
plt.show()

# %%
plt.figure()
plt.hist2d(df_all['chm'], df_all['jet_jes'], bins=(100, 60), norm=mpl.colors.LogNorm())
plt.colorbar()
plt.ylabel('jet_jes')
plt.xlabel('chm')
plt.show()

# %%
plt.figure()
bins = np.linspace(0, 50, 25)
plt.hist(df_all['chm'][(df_all['jet_pt']>150) & 
                             (df_all['jet_pt']<180) & 
                             (df_all['jet_eta']>-0.5) & 
                             (df_all['jet_eta']<0.5)], bins, label='150<pt<180, |eta|<0.5', alpha=0.5, normed=True)
plt.hist(df_all['chm'][(df_all['jet_pt']>150) & 
                             (df_all['jet_pt']<180) & 
                             (df_all['jet_eta']>-0.5) & 
                             (df_all['jet_eta']<0.5) &
                             (df_all['jet_jes'] > 1.0)], bins, label='150<pt<180, |eta|<0.5, jes > 1.1', alpha=0.5, normed=True)
plt.hist(df_all['chm'][(df_all['jet_pt']>150) & 
                             (df_all['jet_pt']<180) & 
                             (df_all['jet_eta']>-0.5) & 
                             (df_all['jet_eta']<0.5) &
                             (df_all['jet_jes'] < 1.0)], bins, label='150<pt<180, |eta|<0.5, jes < 0.9', alpha=0.5, normed=True)
plt.xlabel('Charged Hadron Multiplicity')
plt.legend(loc='lower right')
plt.show()
# Out:
# /cvmfs/cms.cern.ch/slc6_amd64_gcc530/external/py2-matplotlib/1.5.2-njopjo/lib/python2.7/site-packages/matplotlib/axes/_axes.py:5991: RuntimeWarning: invalid value encountered in true_divide
#   m = (m.astype(float) / db) / m.sum()

# %% [markdown]
# ## Finish preprocessing

# %% [markdown]
# #### Normalize variables

# %%
from sklearn.preprocessing import StandardScaler
scaler = StandardScaler()
df_all['scaled_pt'] = scaler.fit_transform(np.log10(df_all['jet_pt']).values.reshape(-1,1))
df_all['jet_eta'] /= 5.0
df_all['jet_images'] = df_all['jet_images']/df_all['jet_images'].apply(np.max)

# %% [markdown]
# #### Check normalized variables

# %%
plt.figure(figsize=(12, 4))
plt.subplot(1,2,1)
plt.hist(df_all['scaled_pt'])
plt.yscale('log')
plt.subplot(1,2,2)
plt.hist(df_all['jet_eta'])
plt.show()

# %%
avg_image = np.sum(df_all.jet_images)/len(df_all)

fig, ax = plt.subplots()
cax = ax.matshow(avg_image.reshape((nx, ny)), norm=mpl.colors.LogNorm())
cbar = fig.colorbar(cax, ticks=[0.0000001, 0.00001, 0.001, 0.1, 1])

# %% [markdown]
# #### Split data into train/val/test sets and save files

# %%
from sklearn.model_selection import train_test_split
df_all_train, df_all_val = train_test_split(df_all, train_size=0.8, random_state = seed)
# df_all_val, df_all_test = train_test_split(df_all_val, train_size=0.5, random_state=seed)

print('Training events = {}, Validation events = {}, Testing events = {}'.format(df_all_train.shape[0], df_all_val.shape[0], 0))

# %%
# Remove intermediary files due to disk space limitations
if True:
    for i in range(first_file, last_file+1):
        if i==8: continue; ## Missing file 8
        os.system('rm data/{}/df_jets_{}_{}.pkl'.format(radius, radius, i))

# %%
# Save combined dfs to disk
df_all_train.to_pickle('data/{}/df_jets_{}_train.pkl'.format(radius, radius))
df_all_val.to_pickle('data/{}/df_jets_{}_val.pkl'.format(radius, radius))
